# %%
from collections import deque
def levelOrderTraversal(root):
    queue = deque([root])
    result = []
    
    while queue:
        levelSize = len(queue)
        currentLevel = []
        
        for q in range(levelSize):
            node = queue.popleft()
            currentLevel.append(node.value)
            
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        
        result.append(currentLevel)
        
    return result
